# %%
# %pip install seaborn matplotlib pandas numpy
# %pip install scikit-learn joblib streamlit
import pandas as pd
df = pd.read_csv(r"/Users/suhaas/Downloads/creditcard.csv")
df
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 294 kB 5.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 7.8 MB 3.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 10.8 MB 7.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.3 MB 7.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.7 MB 8.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.9 MB 12.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 249 kB 14.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 122 kB 8.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 64 kB 5.9 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 348 kB 8.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 509 kB 13.1 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
#so class 0 is not fraud and class 1 is fraud...only 173 of 69.5k is fraud

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
for col in df.columns:
    if df[col].isnull().sum() > 0:
        df[col].fillna(df[col].mode()[0], inplace=True)

df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.head(100)
# Out:
#     Time        V1        V2        V3        V4        V5        V6  \
# 0    0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1    0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2    1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3    1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4    2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ..   ...       ...       ...       ...       ...       ...       ...
# 95  64.0 -0.658305  0.406791  2.037461 -0.291298  0.147910 -0.350857
# 96  64.0  0.959602  0.370711  0.888613  2.343244  0.352491  1.365515
# 97  67.0 -0.653445  0.160225  1.592256  1.296832  0.997175 -0.343000
# 98  67.0 -1.494668  0.837241  2.628211  3.145414 -0.609098  0.258495
# 99  68.0  1.232996  0.189454  0.491040  0.633673 -0.511574 -0.990609
#
#           V7        V8        V9  ...       V21       V22       V23       V24  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='Class',data=df)
plt.show()

# %%
#i cant say i have 99% accuracy cuz fraudsa are very less

# %%
sns.boxplot(x='Class', y='Amount', data=df)
plt.show()

# %%
#not very high losses of amts

# %%
from sklearn.model_selection import train_test_split
X=df.drop('Class',axis=1)

# %%
y = df['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(class_weight='balanced', max_iter=1000)
lr.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
from sklearn.metrics import (accuracy_score,precision_score,recall_score,f1_score,roc_auc_score,confusion_matrix)

# %%
def evaluate(model, X_test, y_test):
    y_prob = model.predict_proba(X_test)[:,1]
    y_pred = (y_prob>0.8).astype(int)
    
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Precision:", precision_score(y_test, y_pred))
    print("Recall:", recall_score(y_test, y_pred))
    print("F1:", f1_score(y_test, y_pred))
    print("ROC-AUC:", roc_auc_score(y_test, y_prob))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# %%
evaluate(lr,X_test_scaled,y_test)
# Out:
# Accuracy: 0.9917664407850848
# Precision: 0.1596330275229358
# Recall: 0.8877551020408163
# F1: 0.27060653188180406
# ROC-AUC: 0.9720834996210077
# Confusion Matrix:
#  [[56406   458]
#  [   11    87]]

# %%
#using log reg we are getting gud enuf result...now lets try with random forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 50,class_weight = 'balanced',random_state = 42)
rf.fit(X_train_scaled,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=50,
#                        random_state=42)

# %%
evaluate(rf,X_test_scaled,y_test)
# Out:
# Accuracy: 0.9992275552122467
# Precision: 0.9655172413793104
# Recall: 0.5714285714285714
# F1: 0.717948717948718
# ROC-AUC: 0.9533635749600909
# Confusion Matrix:
#  [[56862     2]
#  [   42    56]]

# %%
#with threshold 0.8 we get most accurate results so we set it that

# %%
#now using gradient boosting
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(n_estimators=50, random_state=42)
gb.fit(X_train_scaled, y_train)
# Out:
# GradientBoostingClassifier(n_estimators=50, random_state=42)

# %%
evaluate(gb,X_test_scaled,y_test)
# Out:
# Accuracy: 0.9983322214809873
# Precision: 0.5454545454545454
# Recall: 0.1836734693877551
# F1: 0.2748091603053435
# ROC-AUC: 0.3468859283302516
# Confusion Matrix:
#  [[56849    15]
#  [   80    18]]

# %%
#since for fraud detection its okay if we lose a couple of non-frauds but we need to catch almost all frauds...
#so FN should be less so thats first priority...so best avg is given by random forest model so we will use that for deployment

# %%
#we could calculate the avg amt of fraud vs non fraud and multiply it with FN and FP repectively...which ever causes
#a bigger loss we could try to minimize that or select a model that prioritizes that.

# %%
import pickle
with open('models/fraud_model.pkl','wb') as f:
    pickle.dump(rf, f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 2
#       1 import pickle
# ----> 2 with open('models/fraud_model.pkl','wb') as f:
#       3     pickle.dump(rf, f)
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/fraud_model.pkl'
